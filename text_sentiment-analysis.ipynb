# %% [markdown]
# # Sentiment Analysis in Python
#
# This notebook is part of a tutorial that can be found on my [youtube channel here](https://www.youtube.com/channel/UCxladMszXan-jfgzyeIMyvw), please check it out!
#
# In this notebook we will be doing some sentiment analysis in python using two different techniques:
# 1. VADER (Valence Aware Dictionary and sEntiment Reasoner) - Bag of words approach
# 2. Roberta Pretrained Model from 🤗
# 3. Huggingface Pipeline

# %% [markdown]
# # Step 0. Read in Data and NLTK Basics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %%
# Read in data
df = pd.read_csv(r'C:\Users\Dell\Desktop\Minor\Dataset\Reviews.csv')
print(df.shape)
df = df.head(500)
print(df.shape)
# Out:
# (568454, 10)
# (500, 10)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# ## Quick EDA

# %%
ax = df['Score'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('Review Stars')
plt.show()

# %% [markdown]
# ## Basic NLTK

# %%
example = df['Text'][50]
print(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
import nltk
#nltk.download('punkt')

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# !pip install nltk
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# # Step 1. VADER Seniment Scoring
#
# We will use NLTK's `SentimentIntensityAnalyzer` to get the neg/neu/pos scores of the text.
#
# - This uses a "bag of words" approach:
#     1. Stop words are removed
#     2. each word is scored and combined to a total score.

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('I am so happy!')
# Out:
# {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'compound': 0.6468}

# %%
sia.polarity_scores('This is the worst thing ever.')
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Run the polarity score on the entire dataset
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(df, how='left')

# %%
# Now we have sentiment score and metadata
vaders.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# ...

# %% [markdown]
# ## Plot VADER results

# %%
ax = sns.barplot(data=vaders, x='Score', y='compound')
ax.set_title('Compund Score by Amazon Star Review')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Step 3. Roberta Pretrained Model
#
# - Use a model trained of a large corpus of data.
# - Transformer model accounts for the words but also the context related to other words.

# %%
# !pip install transformers
# Out:
# ...
#      ---------------------------------------- 0.0/121.5 kB ? eta -:--:--
#      -------------------------- ------------ 81.9/121.5 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 121.5/121.5 kB 1.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#     --------------------------------------- 0.2/7.7 MB 5.1 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/7.7 MB 3.8 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/7.7 MB 2.6 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/7.7 MB 2.7 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/7.7 MB 2.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/7.7 MB 2.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.2/7.7 MB 3.0 MB/s eta 0:00:03
#    ------- -------------------------------- 1.5/7.7 MB 3.2 MB/s eta 0:00:02
# ...

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[47], line 3
#       1 MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
#       2 tokenizer = AutoTokenizer.from_pretrained(MODEL)
# ----> 3 model = AutoModelForSequenceClassification.from_pretrained(MODEL)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1222, in DummyObject.__getattribute__(cls, key)
#    1220 if key.startswith("_") and key != "_from_config":
#    1221     return super().__getattribute__(key)
# -> 1222 requires_backends(cls, cls._backends)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\utils\import_utils.py:1201, in requires_backends(obj, backends)
#    1199 # Raise an error for users who might not realize that classes without "TF" are torch-only
# ...

# %%
from transformers import TFAutoModelForSequenceClassification, AutoTokenizer

MODEL = "cardiffnlp/twitter-roberta-base-sentiment"

# Initialize the tokenizer and model for TensorFlow
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)

# Now you have loaded the model and tokenizer for TensorFlow
# Out:
# ...
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.7 GB 6.1 MB/s eta 0:07:27
#      ---------------------------------------- 0.0/2.7 GB 9.3 MB/s eta 0:04:53
#      ---------------------------------------- 0.0/2.7 GB 11.1 MB/s eta 0:04:05
#      ---------------------------------------- 0.0/2.7 GB 12.4 MB/s eta 0:03:39
#      ---------------------------------------- 0.0/2.7 GB 12.8 MB/s eta 0:03:33
#      ---------------------------------------- 0.0/2.7 GB 13.8 MB/s eta 0:03:17
#      ---------------------------------------- 0.0/2.7 GB 11.1 MB/s eta 0:04:05
#      ---------------------------------------- 0.0/2.7 GB 14.4 MB/s eta 0:03:10
#      ---------------------------------------- 0.0/2.7 GB 14.2 MB/s eta 0:03:12
#      ---------------------------------------- 0.0/2.7 GB 14.5 MB/s eta 0:03:08
# ...

# %%
# VADER results on example
print(example)
sia.polarity_scores(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
from transformers import TFAutoModelForSequenceClassification, AutoTokenizer
import tensorflow as tf

MODEL = "cardiffnlp/twitter-roberta-base-sentiment"

# Initialize the tokenizer and model for TensorFlow
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)

# Encode the text using the tokenizer
example = "Your text here."
encoded_text = tokenizer(example, return_tensors='tf')  # Use 'tf' for TensorFlow tensors

# Make predictions with the TensorFlow model
output = model(encoded_text)

# Convert the output tensor to a NumPy array for further processing if needed
scores = tf.nn.softmax(output.logits).numpy()
scores_dict = {
    'roberta_neg': scores[0, 0],
    'roberta_neu': scores[0, 1],
    'roberta_pos': scores[0, 2]
}
print(scores_dict)
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# {'roberta_neg': 0.14145873, 'roberta_neu': 0.75036603, 'roberta_pos': 0.10817531}

# %%
# Run for Roberta Model
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[50], line 2
#       1 # Run for Roberta Model
# ----> 2 encoded_text = tokenizer(example, return_tensors='pt')
#       3 output = model(**encoded_text)
#       4 scores = output[0][0].detach().numpy()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\tokenization_utils_base.py:2790, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2788     if not self._in_target_context_manager:
#    2789         self._switch_to_input_mode()
# ...

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
from transformers import TFAutoModelForSequenceClassification, AutoTokenizer
import tensorflow as tf

MODEL = "cardiffnlp/twitter-roberta-base-sentiment"

# Initialize the tokenizer and model for TensorFlow
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)

# Create a function to calculate sentiment scores
def calculate_sentiment_scores(text):
    # Encode the text using the tokenizer
    encoded_text = tokenizer(text, return_tensors='tf')
    
    # Make predictions with the TensorFlow model
    output = model(encoded_text)
    
    # Calculate softmax scores
    scores = tf.nn.softmax(output.logits)
    
    return scores[0].numpy()

# Initialize an empty dictionary for results
res = {}

for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['Text']
        myid = row['Id']
        
        # Calculate sentiment scores using the function
        sentiment_scores = calculate_sentiment_scores(text)
        
        # Rename keys and add to the results dictionary
        sentiment_scores_rename = {}
        sentiment_scores_rename['roberta_neg'] = sentiment_scores[0]
        sentiment_scores_rename['roberta_neu'] = sentiment_scores[1]
        sentiment_scores_rename['roberta_pos'] = sentiment_scores[2]
        
        res[myid] = sentiment_scores_rename
    except RuntimeError:
        print(f'Broke for id {myid}')

# Now res contains the sentiment scores for each text
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[63], line 32
#      29 myid = row['Id']
#      31 # Calculate sentiment scores using the function
# ---> 32 sentiment_scores = calculate_sentiment_scores(text)
#      34 # Rename keys and add to the results dictionary
#      35 sentiment_scores_rename = {}
#
# Cell In[63], line 16, in calculate_sentiment_scores(text)
# ...

# %%
# Define the maximum sequence length of the model
max_seq_length = 514

def calculate_sentiment_scores(text):
    # Truncate or split text to fit within the maximum sequence length
    if len(text) > max_seq_length:
        text = text[:max_seq_length]

    # Encode the text using the tokenizer
    encoded_text = tokenizer(text, return_tensors='tf')
    
    # Make predictions with the TensorFlow model
    output = model(encoded_text)
    
    # Calculate softmax scores
    scores = tf.nn.softmax(output.logits)
    
    return scores[0].numpy()

# %%
max_sequence_length = tokenizer.model_max_length
print("Maximum sequence length:", max_sequence_length)
# Out:
# Maximum sequence length: 1000000000000000019884624838656

# %%
encoded_text = tokenizer.encode(text, max_length=max_sequence_length, truncation=True, padding='max_length', return_tensors='tf')
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 encoded_text = tokenizer.encode(text, max_length=max_sequence_length, truncation=True, padding='max_length', return_tensors='tf')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\tokenization_utils_base.py:2561, in PreTrainedTokenizerBase.encode(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, return_tensors, **kwargs)
#    2524 @add_end_docstrings(
#    2525     ENCODE_KWARGS_DOCSTRING,
#    2526     """
#    (...)
#    2544     **kwargs,
#    2545 ) -> List[int]:
#    2546     """
#    2547     Converts a string to a sequence of ids (integer), using the tokenizer and vocabulary.
#    2548
#    (...)
#    2559             method).
#    2560     """
# -> 2561     encoded_inputs = self.encode_plus(
#    2562         text,
# ...

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['Text']
        myid = row['Id']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[53], line 10
#       8 for key, value in vader_result.items():
#       9     vader_result_rename[f"vader_{key}"] = value
# ---> 10 roberta_result = polarity_scores_roberta(text)
#      11 both = {**vader_result_rename, **roberta_result}
#      12 res[myid] = both
#
# Cell In[52], line 2, in polarity_scores_roberta(example)
#       1 def polarity_scores_roberta(example):
# ----> 2     encoded_text = tokenizer(example, return_tensors='pt')
#       3     output = model(**encoded_text)
#       4     scores = output[0][0].detach().numpy()
#
# ...

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Id'})
results_df = results_df.merge(df, how='left')

# %% [markdown]
# ## Compare Scores between models

# %%
results_df.columns
# Out:
# Index(['Id', 'roberta_neg', 'roberta_neu', 'roberta_pos', 'ProductId',
#        'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %% [markdown]
# # Step 3. Combine and compare

# %%
sns.pairplot(data=results_df,
             vars=['vader_neg', 'vader_neu', 'vader_pos',
                  'roberta_neg', 'roberta_neu', 'roberta_pos'],
            hue='Score',
            palette='tab10')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'vader_neg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 sns.pairplot(data=results_df,
# ...

# %% [markdown]
# # Step 4: Review Examples:
#
# - Positive 1-Star and Negative 5-Star Reviews
#
# Lets look at some examples where the model scoring and review score differ the most.

# %%
results_df.query('Score == 1') \
    .sort_values('roberta_pos', ascending=False)['Text'].values[0]
# Out:
# 'Buyer Beware Please! This sweetener is not for everybody.  Maltitol is an alcohol sugar and can be undigestible in the body.  You will know a short time after consuming it if you are one of the unsuspecting many who cannot digest it by the extreme intestinal bloating and cramping and massive amounts of gas a person can experience. Nausea, diarrhea & headaches can also be experienced. I learned my lesson the hard way years ago when I fell in love with the sugar-free chocolates suzanne sommers used to sell.  I thought I\'d found sugar-free chocolate nirvana at first taste but the bliss was short lived when the terrible side effects of maltitol kicked in.  The discomfort was unlike anything I had ever felt before.  I blew up like a balloon and had very painful abdominal cramping.  As the symptoms passed, this too was very unpleasant.  Though hard for me to believe a low calorie sweetener could be the culprit, all symptoms were gone when I stopped eating the chocolate. My hunch it had s
# ...

# %%
top_text = results_df.query('Score == 1').sort_values('vader_pos', ascending=False)['Text'].values[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14052\2137674567.py in ?()
# ----> 1 top_text = results_df.query('Score == 1').sort_values('vader_pos', ascending=False)['Text'].values[0]
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
# ...

# %%
results_df.query('Score == 1') \
    .sort_values('vader_pos', ascending=False)['Text'].values[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14052\2197355258.py in ?()
#       1 results_df.query('Score == 1') \
# ----> 2     .sort_values('vader_pos', ascending=False)['Text'].values[0]
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
# ...

# %%
# nevative sentiment 5-Star view

# %%
results_df.query('Score == 5') \
    .sort_values('roberta_neg', ascending=False)['Text'].values[0]
# Out:
# 'this was sooooo deliscious but too bad i ate em too fast and gained 2 pds! my fault'

# %%
results_df.query('Score == 5') \
    .sort_values('vader_neg', ascending=False)['Text'].values[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14052\3045319474.py in ?()
#       1 results_df.query('Score == 5') \
# ----> 2     .sort_values('vader_neg', ascending=False)['Text'].values[0]
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
# ...

# %% [markdown]
# # Extra: The Transformers Pipeline
# - Quick & easy way to run sentiment predictions

# %%
from transformers import pipeline

sent_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# ...

# %%
sent_pipeline('I love sentiment analysis!')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9997853636741638}]

# %%
sent_pipeline('Make sure to like and subscribe!')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9991742968559265}]

# %%
sent_pipeline('booo')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9936267137527466}]

# %% [markdown]
# # The End
